# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd drive/My Drive/Colab Notebooks/experiments
# Out:
# /content/drive/My Drive/Colab Notebooks/experiments

# %%
import pandas as pd

# %% [markdown]
# #MOH-X

# %%
predictions = pd.read_csv("stockholm/bert_code/mohx_bert_subs/mohx_submission.csv")

# %%
predictions.shape
# Out:
# (65, 5)

# %%
final = predictions[(predictions['correct_label'] == predictions['prediction'])]
final.shape
# Out:
# (62, 5)

# %%
correct_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==1)]
correct_met.shape
# Out:
# (35, 5)

# %%
correct_met.to_csv("mohx_tp.csv", index=False)

# %%
wrong_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==0)]
wrong_met.shape
# Out:
# (1, 5)

# %%
wrong_met.to_csv("mohx_fn.csv", index=False)

# %%
correct_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==0)]
correct_lit.shape
# Out:
# (27, 5)

# %%
correct_lit.to_csv("mohx_tn.csv", index=False)

# %%
wrong_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==1)]
wrong_lit.shape
# Out:
# (2, 5)

# %%
wrong_lit.to_csv("mohx_fp.csv", index=False)

# %% [markdown]
# #TroFi

# %%
predictions = pd.read_csv("stockholm/bert_code/trofi_bert_subs/trofi_total.csv")

# %%
predictions.shape
# Out:
# (365, 5)

# %%
predictions.head()
# Out:
#                                             sentence  ...  prediction
# 0  Based on the number of acres planted in the sp...  ...           0
# 1  Allen J. Krowe , 56 years old , leaves his job...  ...           0
# 2  Mr. Redford has assembled a great collection o...  ...           0
# 3  There were n't any American casualties reporte...  ...           0
# 4  Mr. Thunberg of Ried Thunberg said the Fed has...  ...           0
#
# [5 rows x 5 columns]

# %%
final = predictions[(predictions['correct_label'] == predictions['prediction'])]
final.shape
# Out:
# (365, 5)

# %%
final.to_csv("trofi_total_correct.csv", index=False)

# %%
correct_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==1)]
correct_met.shape
# Out:
# (144, 5)

# %%
correct_met.to_csv("trofi_tp.csv", index=False)

# %%
wrong_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==0)]
wrong_met.shape
# Out:
# (4, 5)

# %%
wrong_met.to_csv("trofi_fn.csv", index=False)

# %%
correct_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==0)]
correct_lit.shape
# Out:
# (221, 5)

# %%
correct_lit.to_csv("trofi_tn.csv", index=False)

# %%
wrong_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==1)]
wrong_lit.shape
# Out:
# (5, 5)

# %%
wrong_lit.to_csv("trofi_fp.csv", index=False)

# %% [markdown]
# #TroFi-X

# %%
predictions = pd.read_csv("stockholm/bert_code/trofix_bert_subs/trofix_bert_subs.csv")

# %%
predictions.shape
# Out:
# (145, 6)

# %%
predictions.head()
# Out:
#                                             sentence  ...  prediction
# 0  When she hears that prisoners sometimes carve ...  ...           1
# 1  Morty Bennett eats a scallop and shrimp entree...  ...           0
# 2  The latest truce in the week-old battle , whic...  ...           1
# 3  All agree that the state must diversify its in...  ...           1
# 4  `` It floods the area instead of having hot pi...  ...           1
#
# [5 rows x 6 columns]

# %%
final = predictions[(predictions['correct_label'] == predictions['prediction'])]
final.shape
# Out:
# (139, 6)

# %%
final.to_csv("trofix_total_correct.csv", index=False)

# %%
correct_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==1)]
correct_met.shape
# Out:
# (63, 6)

# %%
correct_met.to_csv("trofix_tp.csv", index=False)

# %%
wrong_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==0)]
wrong_met.shape
# Out:
# (2, 6)

# %%
wrong_met.to_csv("trofix_fn.csv", index=False)

# %%
correct_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==0)]
correct_lit.shape
# Out:
# (76, 6)

# %%
correct_lit.to_csv("trofix_tn.csv", index=False)

# %%
wrong_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==1)]
wrong_lit.shape
# Out:
# (4, 6)

# %%
wrong_lit.to_csv("trofix_fp.csv", index=False)

# %% [markdown]
# #ES LCC

# %%
predictions = pd.read_csv("es_lcc_bert_sub.csv")

# %%
predictions.shape
# Out:
# (1854, 7)

# %%
final = predictions[(predictions['correct_label'] == predictions['prediction'])]
final.shape
# Out:
# (1706, 7)

# %%
final.to_csv("es_lcc_total_correct.csv", index=False)

# %%
correct_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==1)]
correct_met.shape
# Out:
# (873, 7)

# %%
correct_met.to_csv("es_lcc_tp.csv", index=False)

# %%
wrong_met = predictions[(predictions['correct_label'] == 1) & (predictions['prediction'] ==0)]
wrong_met.shape
# Out:
# (66, 7)

# %%
wrong_met.to_csv("es_lcc_fn.csv", index=False)

# %%
correct_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==0)]
correct_lit.shape
# Out:
# (833, 7)

# %%
correct_lit.to_csv("es_lcc_tn.csv", index=False)

# %%
wrong_lit = predictions[(predictions['correct_label'] == 0) & (predictions['prediction'] ==1)]
wrong_lit.shape
# Out:
# (82, 7)

# %%
wrong_lit.to_csv("es_lcc_fp.csv", index=False)
