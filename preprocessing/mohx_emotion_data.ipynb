# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd drive/My Drive/Colab Notebooks/experiments/data/Metaphor-Emotion-Data-Files
# Out:
# /content/drive/My Drive/Colab Notebooks/experiments/data/Metaphor-Emotion-Data-Files

# %%
# !pip install contractions
# Out:
# ...
#      |████████████████████████████████| 327kB 13.1MB/s
# ...
#      |████████████████████████████████| 266kB 13.4MB/s
# ...
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.1-cp36-cp36m-linux_x86_64.whl size=84340 sha256=2dcc4bc21924f0aa0f22bd32083dc12956ff10b8f02e6edc641d0e62bcf5baa8
#   Stored in directory: /root/.cache/pip/wheels/e4/ab/f7/cb39270df8f6126f3dd4c33d302357167086db460968cfc80c
# Successfully built pyahocorasick
# ...

# %%
df1 = pd.read_csv('Data-Table1-emotional-or-not.txt', delimiter="\t")
df1.head()
# Out:
#        term  ...         how_much_emotion_is_conveyed
# 0     abuse  ...  the focus word conveys some emotion
# 1    ascend  ...    the focus word conveys no emotion
# 2      shot  ...    the focus word conveys no emotion
# 3  departed  ...    the focus word conveys no emotion
# 4   blister  ...  the focus word conveys some emotion
#
# [5 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(df1.how_much_emotion_is_conveyed)
plt.xlabel('emotion');
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df1.shape
# Out:
# (342, 4)

# %%
df1.to_csv("mohx_emotion.csv", index=False)

# %%
df3 = pd.read_csv('Data-Table3-emotional-or-not.txt', delimiter="\t")
df3.head()
# Out:
#   focus_term        sense  ...         class         how_much_emotion_is_conveyed
# 0        lie      lie#v#5  ...       literal  the focus word conveys some emotion
# 1        rip      rip#v#1  ...       literal    the focus word conveys no emotion
# 2     fasten   fasten#v#3  ...  metaphorical    the focus word conveys no emotion
# 3    wrestle  wrestle#v#4  ...       literal    the focus word conveys no emotion
# 4      shake    shake#v#5  ...  metaphorical  the focus word conveys some emotion
#
# [5 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(df3.how_much_emotion_is_conveyed)
plt.xlabel('emotion');
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df3.shape
# Out:
# (460, 5)
