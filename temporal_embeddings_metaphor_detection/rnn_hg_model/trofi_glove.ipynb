# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model
# Out:
# /content/drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model

# %%
# !python main_trofi.py #glove
# Out:
# Streaming output truncated to the last 5000 lines.
# PRFA performance for  focus verb 67.8082191780822 61.111111111111114 64.28571428571429 70.50938337801608
# Iteration 25950. Validation Loss 0.027432801201939583.
# PRFA performance for  words that are not focus verbs 0.0 nan nan 99.92046132431895
# PRFA performance for  focus verb 83.33333333333333 43.20987654320987 56.91056910569105 71.58176943699732
# Iteration 26100. Validation Loss 0.03311220183968544.
# PRFA performance for  words that are not focus verbs 0.0 nan nan 99.88069198647842
# PRFA performance for  focus verb 67.96875 53.7037037037037 60.0 68.90080428954424
# Iteration 26250. Validation Loss 0.03061198815703392.
# PRFA performance for  words that are not focus verbs 0.0 nan nan 99.83098031417776
# PRFA performance for  focus verb 65.13157894736842 61.111111111111114 63.05732484076433 68.90080428954424
# Iteration 26400. Validation Loss 0.028070032596588135.
# ...
