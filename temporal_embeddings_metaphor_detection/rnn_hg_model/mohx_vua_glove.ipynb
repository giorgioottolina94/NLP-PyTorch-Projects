# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model
# Out:
# /content/drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model

# %%
# !python main_mohx.py #glove
# Out:
# PyTorch version:
# 1.8.0+cu101
# GPU Detected:
# True
# MOH-X dataset division:  647
# vocab size:  1732
# 100% 2196017/2196017 [00:33<00:00, 65461.34it/s]
# Number of pre-trained word vectors loaded:  1730
# Embeddings mean:  -0.0001946780103025958
# Embeddings stdev:  0.3732253909111023
# Starting epoch 1
# /content/drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model/util.py:301: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   eval_text = Variable(eval_text, volatile=True)
# /content/drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model/util.py:302: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   eval_lengths = Variable(eval_lengths, volatile=True)
# /content/drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model/util.py:303: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...

# %%
# !python main_vua.py #glove
# Out:
# PyTorch version:
# 1.8.0+cu101
# GPU Detected:
# True
# size of training set, validation set:  6323 1550
# vocab size:  13843
# 100% 2196017/2196017 [00:33<00:00, 64599.21it/s]
# Number of pre-trained word vectors loaded:  13404
# Embeddings mean:  0.0005707233212888241
# Embeddings stdev:  0.3729434907436371
# Starting epoch 1
# /content/drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model/util.py:301: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   eval_text = Variable(eval_text, volatile=True)
# /content/drive/My Drive/Colab Notebooks/metaphor_detection_temporal/rnn_hg_model/util.py:302: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   eval_lengths = Variable(eval_lengths, volatile=True)
# ...
